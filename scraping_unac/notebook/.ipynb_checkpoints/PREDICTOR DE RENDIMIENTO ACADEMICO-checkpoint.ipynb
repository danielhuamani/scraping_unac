# %%
import graphlab

# %%
notas = graphlab.SFrame('../data_csv/datasets/data_format_1.csv')
# Out:
# Finished parsing file /home/harol/proyectos_django/scraping_unac/scraping_unac/data_csv/datasets/data_format_1.csv
# Parsing completed. Parsed 79 lines in 0.012293 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,int,float,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/harol/proyectos_django/scraping_unac/scraping_unac/data_csv/datasets/data_format_1.csv
# Parsing completed. Parsed 79 lines in 0.009389 secs.

# %%
notas.print_rows(num_rows=10, num_columns=58)
# Out:
# +---------------+------------------------------+---------------+--------------------+
# | CODIGO ALUMNO | LENGUAJE DE PROGRAMACION III | MATEMATICA IV | DISEÑO DE SISTEMAS |
# +---------------+------------------------------+---------------+--------------------+
# |   1115220374  |              17              |       13      |         17         |
# |   1125210045  |              15              |       11      |         12         |
# |   1115220178  |              16              |       11      |         15         |
# |    100958B    |              14              |       11      |         13         |
# |   1115210198  |              14              |       11      |         17         |
# |    020945A    |              12              |       13      |         12         |
# |   1115210064  |              12              |       11      |         14         |
# |   1115250011  |              10              |       11      |         12         |
# ...

# %%
graphlab.canvas.set_target('ipynb')

# %%
notas.show()

# %%
graphlab.canvas.set_target('browser')

# %%
notas.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:33563/index.html
# Opening Canvas in default web browser.

# %% [markdown]
# ## Dividimos nuestro dataset en data de entrenamiento y para testing

# %%
train_data, test_data = notas.random_split(.8, seed=0)

# %%
train_data.num_rows()
# Out:
# 68

# %%
test_data.num_rows()
# Out:
# 11

# %%
notas_model = graphlab.nearest_neighbor_classifier.create(train_data, target='RENDIMIENTO', features=['INVESTIGACION OPERATIVA I', 'QUIMICA GENERAL', 'MATEMATICA I', 'ORGANIZACION Y METODOS', 'BASE DE DATOS',
                                                                                            'ALGORITMOS Y ESTRUCTURA DE DATOS', 'SIMULACION DE SISTEMAS', 'ADMINISTRACION Y GESTION EMPRESARIAL',
                                                                                            'MATEMATICA II', 'INTRODUCCION A LA INGENIERIA DE SISTEMAS', 'PROYECTOS DE SISTEMAS',
                                                                                            'SISTEMAS DE COMUNICACION', 'SEMINARIO DE TESIS', 'INGENIERIA DE SISTEMAS', 'MATEMATICA DISCRETA',
                                                                                            'LENGUAJE DE PROGRAMACION II', 'GESTION TECNOLOGICA', 'CONSTITUCION DESARROLLO Y DEFENSA NACIONAL',
                                                                                            'ANALISIS ECONOMICO', 'MERCADOTECNIA', 'SISTEMAS DE INFORMACION GERENCIAL', 'MATEMATICA IV',
                                                                                            'LENGUAJE DE PROGRAMACION I', 'TEORIA DE DECISIONES', 'DISEÑO DE SISTEMAS',
                                                                                            'ARQUITECTURA Y ORGANIZACION DEL COMPUTADOR', 'SISTEMAS OPERATIVOS', 'GEOMETRIA DESCRIPTIVA Y DIBUJO',
                                                                                            'METODOLOGIA DE LA INVESTIGACION CIENTIFICA', 'ESTADISTICA APLICADA', 'ANALISIS DE SISTEMAS',
                                                                                            'TALLER DE BASE DE DATOS', 'COMPORTAMIENTO Y DESARROLLO ORGANIZACIONAL', 'MATEMATICA III',
                                                                                            'SISTEMAS DIGITALES', 'LOGISTICA', 'TEORIA GENERAL DE SISTEMAS', 'AUDITORIA DE SISTEMAS',
                                                                                            'MATEMATICA BASICA', 'FISICA III', 'CONTABILIDAD GENERAL', 'ADMINISTRACION DE CENTROS DE INFORMACION',
                                                                                            'FORMULACION Y EVALUACION DE PROYECTOS DE SISTEMAS', 'ESTRATEGIAS EMPRESARIALES Y POLITICAS CORPORATIVAS',
                                                                                            'METODICA DE LA COMUNICACION', 'INGENIERIA ECONOMICA Y FINANCIERA', 'INVESTIGACION OPERATIVA II',
                                                                                            'FISICA I', 'FISICA II', 'LENGUAJE DE PROGRAMACION III', 'CIRCUITOS ELECTRONICOS',
                                                                                            'COSTOS Y PRESUPUESTOS', 'ANALISIS NUMERICO', 'ECONOMIA GENERAL', 'ESTADISTICA'])
# Out:
# Starting ball tree nearest neighbors model training.
# +------------+--------------+
# | Tree level | Elapsed Time |
# +------------+--------------+
# | 0          | 277us        |
# +------------+--------------+

# %%
print notas_model.evaluate(test_data)
# Out:
# WARNING: Ignoring `roc_curve`. Not supported for multi-class classification.
# +--------------+-------------+--------------+
# | Query points | % Complete. | Elapsed Time |
# +--------------+-------------+--------------+
# | 1            | 9           | 73.454ms     |
# | Done         |             | 73.609ms     |
# +--------------+-------------+--------------+
# +--------------+-------------+--------------+
# | Query points | % Complete. | Elapsed Time |
# +--------------+-------------+--------------+
# | 1            | 9           | 291us        |
# | Done         |             | 591us        |
# +--------------+-------------+--------------+
# {'confusion_matrix': Columns:
# 	target_label	str
# 	predicted_label	str
# 	count	int
#
# Rows: 3
#
# Data:
# +--------------+-----------------+-------+
# | target_label | predicted_label | count |
# +--------------+-----------------+-------+
# |      A       |        A        |   3   |
# |      B       |        B        |   6   |
# ...
