# %%
import graphlab

# %%
notas = graphlab.SFrame('../data_csv/datasets/data_format_1.csv')
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1499325874.log
# This non-commercial license of GraphLab Create for academic use is assigned to harol.calzada@gmail.com and will expire on October 01, 2017.
# Finished parsing file /home/harol/proyectos_django/scraping_unac/scraping_unac/data_csv/datasets/data_format_1.csv
# Parsing completed. Parsed 50 lines in 0.099512 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,int,int,int,str,int,int,int,int,int,str,int,int,int,int,int,int,str,str,int,int,int,str,str,str,int,int,str,str,int,int,int,int,int,int,int,str,int,int,int,str,int,int,str,int,int,str,str,int,int,int,int,str,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# ...

# %%
notas
# Out:
# Columns:
# 	CODIGO ALUMNO	str
# 	INGENIERIA ECONOMICA Y FINANCIERA	int
# 	TEORIA GENERAL DE SISTEMAS	int
# 	SISTEMAS OPERATIVOS	int
# 	AUDITORIA DE SISTEMAS	str
# 	METODOLOGIA DE LA INVESTIGACION CIENTIFICA	int
# 	INTRODUCCION A LA INGENIERIA DE SISTEMAS	int
# 	FISICA I	int
# 	PROYECTOS DE SISTEMAS	int
# 	MERCADOTECNIA	int
# 	LENGUAJE DE PROGRAMACION III	str
# 	FISICA III	int
# 	TEORIA DE DECISIONES	int
# 	ECONOMIA GENERAL	int
# 	ADMINISTRACION Y GESTION EMPRESARIAL	int
# 	MATEMATICA III	int
# 	FISICA II	int
# 	ANALISIS NUMERICO	str
# 	ARQUITECTURA Y ORGANIZACION DEL COMPUTADOR	str
# 	CIRCUITOS ELECTRONICOS	int
# 	LENGUAJE DE PROGRAMACION I	int
# 	DISEÑO DE SISTEMAS	int
# 	SEMINARIO DE TESIS	str
# 	MATEMATICA IV	str
# 	ESTADISTICA	str
# 	COMPORTAMIENTO Y DESARROLLO ORGANIZACIONAL	int
# 	ANALISIS DE SISTEMAS	int
# 	SISTEMAS DE COMUNICACION	str
# 	MATEMATICA I	str
# 	INVESTIGACION OPERATIVA I	int
# 	BASE DE DATOS	int
# 	FORMULACION Y EVALUACION DE PROYECTOS DE SISTEMAS	int
# ...

# %%
graphlab.canvas.set_target('ipynb')

# %%
notas.show()
